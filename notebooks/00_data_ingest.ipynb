# %%
# ============================================
# 00 - DATA INGEST
# ============================================

import pandas as pd
from pathlib import Path

# Caminho do dataset
DATA_PATH = Path('../data/internet_adoption.csv')

# Carregar dados
df = pd.read_csv(DATA_PATH)

# -------------------------
# Visão inicial
# -------------------------
print("Formato inicial:", df.shape)
display(df.head())

# -------------------------
# Tipos e valores nulos
# -------------------------
print("\nINFO:")
print(df.info())

print("\nNULOS POR COLUNA:")
print(df.isna().sum())

# -------------------------
# Converter colunas numéricas
# -------------------------

# Lista completa de colunas numéricas REAIS
num_cols = [
    "Population",
    "Internet_Penetration (%)",
    "Broadband_Speed (Mbps)",
    "Mobile_Broadband_Speed (Mbps)",
    "GDP_Per_Capita (USD)",
    "Education_Attainment_Index (%)",
    "Mobile_Data_Usage (GB per User)",
    "Digital_Investment (M USD)",
    "Digital_Literacy_Score (%)",
    "Sentiment_Score (Social Media)",
    "Urban_Population_Split (%)",
    "Rural_Population_Split (%)",
    "Latitude",
    "Longitude",
    "Internet_Access_Cost (USD per Mbps)",
    "Device_Penetration (%)",
    "Cybersecurity_Incidents (Count)",
    "E_Commerce_Penetration (%)",
    "Government_Digital_Policy_Index (%)",
    "Network_Latency (ms)",
    "Cloud_Service_Adoption (%)",
    "IoT_Device_Density (per 1000 people)",
    "AI_Adoption_Index (%)",
    "Data_Privacy_Regulation_Strength (%)",
    "Energy_Consumption_for_Connectivity (kWh)"
]

for c in num_cols:
    if c in df.columns:
        df[c] = pd.to_numeric(df[c], errors='coerce')

# -------------------------
# Tratamento de nulos
# -------------------------

# Exemplo: remover entradas sem valor de adoção da internet
df = df.dropna(subset=["Internet_Penetration (%)"])

# Ou preencher valores ausentes
df = df.fillna(0)

# -------------------------
# Salvar versão tratada
# -------------------------
OUTPUT_PATH = Path('../data/internet_adoption_clean.csv')
df.to_csv(OUTPUT_PATH, index=False)

print("\nArquivo limpo salvo em:", OUTPUT_PATH)
print("Novo formato:", df.shape)
# Out:
# Formato inicial: (6350, 28)
#    Country        Date  Population  Internet_Penetration (%)  \
# 0  Algeria  2015-01-01    25258314                 37.436774
# 1  Algeria  2015-02-01    25258314                 37.484286
# 2  Algeria  2015-03-01    25258314                 37.629677
# 3  Algeria  2015-04-01    25258314                 37.257667
# 4  Algeria  2015-05-01    25258314                 37.492258
#
#    Broadband_Speed (Mbps)  Mobile_Broadband_Speed (Mbps)  \
# 0               46.839032                       8.533871
# 1               47.227500                       8.687500
# 2               47.436129                       8.852903
# 3               47.500000                       9.058333
# 4               47.659677                       8.886452
#
#    GDP_Per_Capita (USD)  Education_Attainment_Index (%)  \
# 0           5327.303548                       45.489677
# 1           5331.729286                       45.555714
# 2           5342.169032                       45.608710
# 3           5354.909667                       45.643333
# 4           5360.973226                       45.662258
#
#    Mobile_Data_Usage (GB per User)  Digital_Investment (M USD)  ...  \
# 0                         2.167742                  164.128065  ...
# 1                         2.185357                  165.386071  ...
# 2                         2.182581                  166.200645  ...
# 3                         2.199000                  166.618667  ...
# 4                         2.205484                  167.409032  ...
#
#    Device_Penetration (%)  Cybersecurity_Incidents (Count)  \
# 0               68.104839                             4174
# 1               68.122500                             3753
# 2               68.108065                             4148
# 3               68.147000                             4032
# 4               68.143548                             4195
#
#   E_Commerce_Penetration (%)  Government_Digital_Policy_Index (%)  \
# 0                  33.408387                            37.136774
# 1                  33.520000                            37.128214
# 2                  33.545806                            37.155806
# 3                  33.579333                            37.120000
# 4                  33.598710                            37.155484
#
#    Network_Latency (ms)  Cloud_Service_Adoption (%)  \
# 0             77.050645                   27.834194
# 1             77.045000                   27.856429
# 2             77.120968                   27.870968
# 3             77.255333                   27.880333
# 4             77.075161                   27.930323
#
#    IoT_Device_Density (per 1000 people)  AI_Adoption_Index (%)  \
# 0                             22.950645              15.652581
# 1                             22.936429              15.681429
# 2                             23.034839              15.686452
# 3                             23.083667              15.706667
# 4                             23.111290              15.729355
#
#    Data_Privacy_Regulation_Strength (%)  \
# 0                             27.985161
# 1                             27.989643
# 2                             27.993548
# 3                             28.010000
# 4                             28.018065
#
#    Energy_Consumption_for_Connectivity (kWh)
# 0                                 248.871935
# 1                                 248.757500
# 2                                 248.524839
# 3                                 248.497333
# 4                                 248.983548
#
# [5 rows x 28 columns]
# INFO:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6350 entries, 0 to 6349
# Data columns (total 28 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    6350 non-null   object
#  1   Date                                       6350 non-null   object
#  2   Population                                 6350 non-null   int64
#  3   Internet_Penetration (%)                   6350 non-null   float64
#  4   Broadband_Speed (Mbps)                     6350 non-null   float64
#  5   Mobile_Broadband_Speed (Mbps)              6350 non-null   float64
#  6   GDP_Per_Capita (USD)                       6350 non-null   float64
#  7   Education_Attainment_Index (%)             6350 non-null   float64
#  8   Mobile_Data_Usage (GB per User)            6350 non-null   float64
#  9   Digital_Investment (M USD)                 6350 non-null   float64
#  10  Digital_Literacy_Score (%)                 6350 non-null   float64
#  11  Sentiment_Score (Social Media)             6350 non-null   float64
#  12  5G_Rollout_Status                          3278 non-null   object
#  13  Urban_Population_Split (%)                 6350 non-null   float64
#  14  Rural_Population_Split (%)                 6350 non-null   float64
#  15  Latitude                                   6350 non-null   float64
#  16  Longitude                                  6350 non-null   float64
#  17  Internet_Access_Cost (USD per Mbps)        6350 non-null   float64
#  18  Device_Penetration (%)                     6350 non-null   float64
#  19  Cybersecurity_Incidents (Count)            6350 non-null   int64
#  20  E_Commerce_Penetration (%)                 6350 non-null   float64
#  21  Government_Digital_Policy_Index (%)        6350 non-null   float64
#  22  Network_Latency (ms)                       6350 non-null   float64
#  23  Cloud_Service_Adoption (%)                 6350 non-null   float64
#  24  IoT_Device_Density (per 1000 people)       6350 non-null   float64
#  25  AI_Adoption_Index (%)                      6350 non-null   float64
#  26  Data_Privacy_Regulation_Strength (%)       6350 non-null   float64
#  27  Energy_Consumption_for_Connectivity (kWh)  6350 non-null   float64
# dtypes: float64(23), int64(2), object(3)
# memory usage: 1.4+ MB
# None
#
# NULOS POR COLUNA:
# Country                                         0
# Date                                            0
# Population                                      0
# Internet_Penetration (%)                        0
# Broadband_Speed (Mbps)                          0
# Mobile_Broadband_Speed (Mbps)                   0
# GDP_Per_Capita (USD)                            0
# Education_Attainment_Index (%)                  0
# Mobile_Data_Usage (GB per User)                 0
# Digital_Investment (M USD)                      0
# Digital_Literacy_Score (%)                      0
# Sentiment_Score (Social Media)                  0
# 5G_Rollout_Status                            3072
# Urban_Population_Split (%)                      0
# Rural_Population_Split (%)                      0
# Latitude                                        0
# Longitude                                       0
# Internet_Access_Cost (USD per Mbps)             0
# Device_Penetration (%)                          0
# Cybersecurity_Incidents (Count)                 0
# E_Commerce_Penetration (%)                      0
# Government_Digital_Policy_Index (%)             0
# Network_Latency (ms)                            0
# Cloud_Service_Adoption (%)                      0
# IoT_Device_Density (per 1000 people)            0
# AI_Adoption_Index (%)                           0
# Data_Privacy_Regulation_Strength (%)            0
# Energy_Consumption_for_Connectivity (kWh)       0
# dtype: int64
#
# Arquivo limpo salvo em: ../data/internet_adoption_clean.csv
# Novo formato: (6350, 28)
